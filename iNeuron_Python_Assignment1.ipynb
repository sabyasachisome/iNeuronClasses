# %% [markdown]
# 1. Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included).
# The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
def getDivisibleBy7NotBy5(start, stop):
  return [num for num in range(start, stop+1) if (num%7==0 and num%5!=0)]

# %%
# o/p:
getDivisibleBy7NotBy5(2000, 3000)

# %% [markdown]
# 2. Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
def getReverseName():
  print(' '.join(sorted([str(input('Enter name: ')) for i in range(2)], reverse=True)))

# %%
# o/p
getReverseName()

# %% [markdown]
# 3. Write a Python program to find the volume of a sphere with diameter 12 cm.
# Formula: V=4/3 * π * r^3

# %%
def findVolume(diameter= 12):
  print((4/3)*(22/7)*((diameter/2)**3))

# %%
# o/p
findVolume(6)
